# %% [markdown]
# <a href="https://colab.research.google.com/github/zackhalepoto/Data_Science_Projects/blob/main/AmazonScraping_using_beautifulSoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
search_query="shirts+for+men"

# %%
base_url="https://www.amazon.com/s?k="

# %%
url=base_url+search_query
url
# Out:
# 'https://www.amazon.com/s?k=shirts+for+men'

# %%
header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36',
        'referer':'https://www.amazon.com/s?k=shirts+for+men&crid=12PBZEM8I68PG&sprefix=shirts+for+men%2Caps%2C756&ref=nb_sb_noss_1'}

# %%
search_response=requests.get(url,headers=header)
search_response
# Out:
# <Response [200]>

# %%
search_response.status_code
# Out:
# 200

# %%
search_response.text
# Out:
# '<!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(
# ...

# %%
search_response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='i18n-prefs', value='USD', port=None, port_specified=False, domain='.amazon.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1699025836, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id', value='144-9622998-5494751', port=None, port_specified=False, domain='.amazon.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1699025836, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id-time', value='2082787201l', port=None, port_specified=False, domain='.amazon.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1699025836, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
cookie={} # insert request cookies within{}
def getAmazonSearch(search_query):
    url="https://www.amazon.com/s?k="+search_query
    print(url)
    page=requests.get(url,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
# ## function to get the contents of individual product pages using 'data-asin' number (unique identification number)
def Searchasin(asin):
    url="https://www.amazon.com/shirts-for-men/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
# ## function to pass on the link of 'see all reviews' and extract the content

def Searchreviews(review_link):
    url="https://www.amazon.com"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"
url
# Out:
# 'https://www.amazon.com/s?k=shirts+for+men'

# %%
# ## First page product reviews extraction
product_names=[]
response =getAmazonSearch('shirts+for+men')
soup=BeautifulSoup(response.content)
for i in soup.findAll("span",{'class':'a-size-base-plus a-color-base a-text-normal'}):
    # the tag which is common for all the names of products
    product_names.append(i.text) #adding the product names to the list
# Out:
# https://www.amazon.com/s?k=shirts+for+men

# %%
product_names
# Out:
# ["Men's Buck Camp Flannel Shirt",
#  "Men's Crew T-Shirts, Multipack, Style G1100",
#  "Men's T-Shirts, Men's BeefyT Henley Shirts, Men's Cotton Long Sleeve Shirts",
#  "Premium Men's T-Shirts - Crew Neck Soft Fitted Tees S - 4XL Fresh Classic Tshirts",
#  "Men's Heavyweight Crewneck Short Sleeve T-Shirt",
#  "Men's Hipster Floral Printed Long Sleeve Cotton Casual Button Down Dress Shirts",
#  "Men's Stretch Muscle Tshirts Long Sleeve Knit Tees Casual Slim Fit Polo Shirts",
#  "Men's Short Sleeve 100% Cotton Pique Color Block Polo Shirt",
#  "Men's Navtech Tee",
#  "by Kingsize Men's Big & Tall Short Sleeve Denim & Twill Shirt",
#  "Men's Performance Cotton Tank Top Shirt",
#  'Men’s Fourche Mountain Long Sleeve River Guide Fishing Shirt',
#  'Mens Legend Short Sleeve Tee',
#  "Men's Regular-fit Long-Sleeve Solid Pocket Oxford Shirt",
#  "4 Pack: Men's Dry-Fit Moisture Wicking Performance Long Sleeve T-Shirt, UV Sun Protection Outdoor Active Athletic Crew Top",
# ...

# %%
len(product_names)
# Out:
# 58

# %%
data_asin=[]
response=getAmazonSearch('shirts+for+men')
soup=BeautifulSoup(response.content)
for i in soup.findAll("div",{'class':"sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20"}):
    data_asin.append(i['data-asin'])
# Out:
# https://www.amazon.com/s?k=shirts+for+men

# %%
response.status_code
# Out:
# 200

# %%
len(data_asin)
# Out:
# 48

# %%
data_asin
# Out:
# ['B01K0ETCWM',
#  'B077ZJXCTS',
#  'B01027781O',
#  'B00JMKLNAA',
#  'B07F2GR8F8',
#  'B00JUMDV0U',
#  'B0775MHKD6',
#  'B002GHC19I',
#  'B08BLLHYKC',
#  'B07TF75KXT',
#  'B00KBZUF0E',
#  'B07NWY7XK9',
#  'B07VTSD48H',
#  'B07D13B3N1',
#  'B071GWD5QJ',
#  'B077ZJC1N9',
#  'B07BJL5XL6',
#  'B07CNSM68T',
#  'B08F2P8CS9',
#  'B08287SBCV',
#  'B01IXFP9S6',
#  'B083P3QPH6',
#  'B09B5CP1SQ',
#  'B09TQLQFHX',
#  'B01N1PRLGT',
#  'B000HOBYDG',
#  'B0002SSQBA',
#  'B0738FQTZN',
#  'B00VTVAR2U',
#  'B07MFBYCQY',
#  'B07756DQ8K',
#  'B0B82K47M6',
#  'B005DIJN5C',
#  'B078B27ZBY',
#  'B07JHQ8TGZ',
#  'B007BLNK6C',
#  'B07LG855G4',
#  'B086L4XXGF',
#  'B0BDQQDDTG',
#  'B01GH5GC7Q',
#  'B0089OQ2YM',
#  'B0866D9X64',
#  'B0006SCZUE',
#  'B07F258HBH',
#  'B0867288RR',
#  'B0785XTS55',
#  'B0132MGY98',
#  'B07JHY5F25']

# %%
# #### By passing the data-asin numbers, we can extract the 'see all reviews' link for each product in the page
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.com/shirts-for-men/dp/B01K0ETCWM
# https://www.amazon.com/shirts-for-men/dp/B077ZJXCTS
# https://www.amazon.com/shirts-for-men/dp/B01027781O
# https://www.amazon.com/shirts-for-men/dp/B00JMKLNAA
# https://www.amazon.com/shirts-for-men/dp/B07F2GR8F8
# https://www.amazon.com/shirts-for-men/dp/B00JUMDV0U
# https://www.amazon.com/shirts-for-men/dp/B0775MHKD6
# https://www.amazon.com/shirts-for-men/dp/B002GHC19I
# https://www.amazon.com/shirts-for-men/dp/B08BLLHYKC
# https://www.amazon.com/shirts-for-men/dp/B07TF75KXT
# https://www.amazon.com/shirts-for-men/dp/B00KBZUF0E
# https://www.amazon.com/shirts-for-men/dp/B07NWY7XK9
# https://www.amazon.com/shirts-for-men/dp/B07VTSD48H
# https://www.amazon.com/shirts-for-men/dp/B07D13B3N1
# https://www.amazon.com/shirts-for-men/dp/B071GWD5QJ
# https://www.amazon.com/shirts-for-men/dp/B077ZJC1N9
# https://www.amazon.com/shirts-for-men/dp/B07BJL5XL6
# https://www.amazon.com/shirts-for-men/dp/B07CNSM68T
# ...

# %%
len(link)
# Out:
# 90

# %%
link
# Out:
# ['/Legendary-Whitetails-Mens-Flannel-Shirt/product-reviews/B0964SCSTB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Legendary-Whitetails-Mens-Flannel-Shirt/product-reviews/B0964SCSTB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Gildan-T-Shirts-Multipack-Style-G1100/product-reviews/B0B5M2J2KJ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Gildan-T-Shirts-Multipack-Style-G1100/product-reviews/B0B5M2J2KJ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Hanes-O5719-Mens-Heavyweight-Henley/product-reviews/B07TJ9Y1KB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Hanes-O5719-Mens-Heavyweight-Henley/product-reviews/B07TJ9Y1KB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/NIKE-Mens-Legend-Short-Sleeve/product-reviews/B0096E59S4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
# ...

# %%
reviews=[]
for j in range(len(link)):
    for k in range(100):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# Streaming output truncated to the last 5000 lines.
# https://www.amazon.com/Amazon-Essentials-Slim-Fit-Long-Sleeve-Henley/product-reviews/B07BJKW5PZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.com/Amazon-Essentials-Slim-Fit-Long-Sleeve-Henley/product-reviews/B07BJKW5PZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.com/Amazon-Essentials-Slim-Fit-Long-Sleeve-Henley/product-reviews/B07BJKW5PZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.com/Amazon-Essentials-Slim-Fit-Long-Sleeve-Henley/product-reviews/B07BJKW5PZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.com/Amazon-Essentials-Slim-Fit-Long-Sleeve-Henley/product-reviews/B07BJKW5PZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
len(reviews)

# %%
rev={'reviews':reviews}
review_data=pd.DataFrame.from_dict(rev)
pd.set_option('max_colwidth',800)

# %%
review_data.head(5)
# Out:
# Empty DataFrame
# Columns: [reviews]
# Index: []

# %%
review_data.shape
# Out:
# (2257, 1)

# %%
review_data.to_csv('Scraping_reviews.csv')

# %%
review_data.to_excel('C:\\Users\\Salas Ali\\Desktop\\amazon_reviews.xlsx', index=False)

# %%
review_data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               reviews
# ...
